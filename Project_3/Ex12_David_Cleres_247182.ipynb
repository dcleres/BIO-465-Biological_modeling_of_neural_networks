# %% [markdown]
# # Solution Graded Exercise 12: Spatial Working Memory (Compte et. al.)

# %% [markdown]
# first name: David
#
# last name: CLERES
#
# sciper: 247182
#
# date: 22.05.2018
#
# *Your teammate*
#
# first name of your teammate: Nicolas
#
# last name of your teammate: LESIMPLE
#
# sciper of your teammate: 237699
#
#
# Note: You are allowed to discuss the concepts with your class mates. You are not allowed to share code. You have to understand every line of code you write in this notebook. We will ask you questions about your submission during a fraud detection session during the last week of the semester.
#
# ** Remember **
#
# If you are asked for plots: The appearance of the plots (labelled axes, ** useful scaling **, etc.) is important!
#
# If you are asked for discussions: Answer in a precise way and try to be concise.
#
#
# ** Submission **
#
# Rename this notebook to Ex12_FirstName_LastName_Sciper.ipynb and upload that single file on moodle before the deadline.
#
# ** Link to the exercise **
#
# http://neuronaldynamics-exercises.readthedocs.io/en/latest/exercises/spatial-working-memory.html

# %% [markdown]
# ## \* \* \* \* IMPORTANT: neurodynex update  \* \* \* \*
#
# This exercise requires an update of the neurodynex package. For the update, please run the following lines in your terminal:
#
# > source activate bmnn
# >
# > conda update -c brian-team -c epfl-lcn neurodynex

# %% [markdown]
# # Exercise 12.1. Spontaneous bump formation

# %% [markdown]
# ### Exercise 12.1.1. Question: External poisson population
# 1) By default, how many neurons are in the external poisson population?
#
# ANSWER: By looking at the source code and the paramter "N_extern_poisson" we see that the value is 1000.
#
# 2) Using the default parameters, what is the average number of spikes/second an excitatory neuron receives from the external population?
#
# ANSWER: The external poisson population is of size 1000, the firing rate of the population is of 1.4 Hz. This means that an excitatory neuron recieves, on average 1.4 spikes / second from the external population.
#
# #### [1 + 1  points]

# %% [markdown]
# 3) We use the Brian2 PoissonInput to implement the external population. Which post-synaptic variable is targeted by a presynaptic (poisson) spike?
# #### [1  points]
#
# ANSWER: Brian2 PoissonInput enables the user to specify a target population (which were either the excitatory or inhibitory neuron population). As a second paramter one could chose the target_variable which wil be the modified postsynaptic variable. In both cases s_AMPA was given as the target variable. This could reflect the concentration of the s-AMPA agonist.

# %% [markdown]
# 4) The dynamics of that variable are defined in the equations excit_lif_dynamics (still in the source code of simulate_wm). What is the time-scale of that variable (in milliseconds)?
#
# #### [1  points]
#
# ANSWER: tau_AMPA = $.9 \times 2.0 \times b2.ms$ = 18 ms

# %% [markdown]
# ### Exercise 12.1.2. Question: Unstructured input

# %%
# %matplotlib inline
import brian2 as b2
from neurodynex.working_memory_network import wm_model
from neurodynex.tools import plot_tools

print('Plot for external population at 1.3Hz : ')
rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, idx_monitored_neurons_excit, rate_monitor_inhib, spike_monitor_inhib, voltage_monitor_inhib, idx_monitored_neurons_inhib, w_profile = wm_model.simulate_wm(sim_time=800. * b2.ms, poisson_firing_rate=1.3 * b2.Hz, sigma_weight_profile=20., Jpos_excit2excit=1.6)
plot_tools.plot_network_activity(rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, t_min=0. * b2.ms)
# Out:
# /Users/davidcleres/miniconda2/envs/bmnn/lib/python2.7/site-packages/brian2/core/variables.py:174: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   return np.issubdtype(np.bool, self.dtype)
# WARNING    /Users/davidcleres/miniconda2/envs/bmnn/lib/python2.7/site-packages/brian2/core/variables.py:174: FutureWarning: Conversion of the second argument of issubdtype from `bool` to `np.generic` is deprecated. In future, it will be treated as `np.bool_ == np.dtype(bool).type`.
#   return np.issubdtype(np.bool, self.dtype)
#  [py.warnings]
# Plot for external population at 1.3Hz :
# WARNING    /Users/davidcleres/miniconda2/envs/bmnn/lib/python2.7/site-packages/brian2/groups/group.py:258: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   elif not np.issubdtype(index_array.dtype, np.int):
#  [py.warnings]
# INFO       width adjusted from 1. ms to 1.05 ms [brian2.monitors.ratemonitor.adjusted_width]
# WARNING    /Users/davidcleres/miniconda2/envs/bmnn/lib/python2.7/site-packages/brian2/monitors/statemonitor.py:287: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(dtype, np.int):
#  [py.warnings]
# WARNING    /Users/davidcleres/miniconda2/envs/bmnn/lib/python2.7/site-packages/brian2/monitors/statemonitor.py:57: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(dtype, np.int) and not isinstance(item, np.ndarray):
#  [py.warnings]
# (<matplotlib.figure.Figure at 0x1025a0e10>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1082498d0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1084f6ad0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x10a2ea210>)

# %%
print('Plot for external population at 2.2Hz : ')
rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, idx_monitored_neurons_excit, rate_monitor_inhib, spike_monitor_inhib, voltage_monitor_inhib, idx_monitored_neurons_inhib, w_profile = wm_model.simulate_wm(sim_time=800. * b2.ms, poisson_firing_rate=2.2 * b2.Hz, sigma_weight_profile=20., Jpos_excit2excit=1.6)
plot_tools.plot_network_activity(rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, t_min=0. * b2.ms)
# Out:
# Plot for external population at 2.2Hz :
# (<matplotlib.figure.Figure at 0x104e35c50>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1073a7590>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1192f0e50>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1008d2210>)

# %% [markdown]
# 1) Without coding, from the plot: What is the population activity (mean firing rate) of the excitatory population at different points in time?
#
# 2) Change the firing rate of the external population to 2.2Hz. What do you observe?
#
# #### [2  + 2  points]
#
# ANSWER 1: Firing rate ext_population =1.3 Hz. This value could also be recognized on the plots. It is possible to see many histogramm bars with height around 1.3 Hz on the middle plot (A(t) in function of time). Furthermore, the distrubution of which neuron fires when and where seems to be random according to the raster plot.
#
# ANSWER 2: Firing rate ext_population = 2.2 Hz. It is possible to recognize that the activity increases whereas before the activity oscillated around the 1.3Hz mark. Here it is not the case, first the activity is stable around 2 Hz but then it increases rapidly to higher frequencyvalues around 10 Hz. Futhermore, by looking at the raster plot one could recognise that the neurons which are firing are more and more clustered together in a given area.

# %%
for i in range (5):
    rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, idx_monitored_neurons_excit, rate_monitor_inhib, spike_monitor_inhib, voltage_monitor_inhib, idx_monitored_neurons_inhib, w_profile = wm_model.simulate_wm(sim_time=800. * b2.ms, poisson_firing_rate=2.2 * b2.Hz, sigma_weight_profile=20., Jpos_excit2excit=1.6)
    plot_tools.plot_network_activity(rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, t_min=0. * b2.ms)

# %% [markdown]
# 3) Run the simulation a few times with r_ext = 2.2 Hz. Describe your observations.
# #### [2   points]

# %% [markdown]
# It is possible to see that the trends are different in function of the simulation. In 3/5 of the cases we could draw the same conclusions as in the previous question. Nevertheless, it was possible to see that the firing cluster was not always located in the same place on the raster plot. However, in the two other experiements the activtity was looking more like was we observed for the 1.3 Hz frequency, meaning that the activity stayed constant.

# %% [markdown]
# ### Exercise 12.1.3. Question: Weight profile

# %%
# %matplotlib inline
import brian2 as b2
from neurodynex.working_memory_network import wm_model
from neurodynex.tools import plot_tools
import matplotlib.pyplot as plt

rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, idx_monitored_neurons_excit, rate_monitor_inhib, spike_monitor_inhib, voltage_monitor_inhib, idx_monitored_neurons_inhib, weight_profile_45 = wm_model.simulate_wm(sim_time=800. * b2.ms, poisson_firing_rate=1.3 * b2.Hz, sigma_weight_profile=20., Jpos_excit2excit=1.6)
plot_tools.plot_network_activity(rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, t_min=0. * b2.ms)

plt.figure()
plt.plot(weight_profile_45)
plt.title('Plot with Jpos_excit2excit = 1.6')
# Out:
# Text(0.5,1,u'Plot with Jpos_excit2excit = 1.6')

# %%
values = [1.1, 1.7, 1.8, 1.9, 2.0, 2.1, 2.2, 2.3, 5] 

for i in range (len(values)): 
    rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, idx_monitored_neurons_excit, rate_monitor_inhib, spike_monitor_inhib, voltage_monitor_inhib, idx_monitored_neurons_inhib, weight_profile_45 = wm_model.simulate_wm(sim_time=800. * b2.ms, poisson_firing_rate=1.3 * b2.Hz, sigma_weight_profile=20., Jpos_excit2excit=values[i])
    plot_tools.plot_network_activity(rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, t_min=0. * b2.ms)

    plt.figure()
    plt.plot(weight_profile_45)
    plt.title('Weight profil for Jpos_excit2_excit = {}'.format(values[i]))
    plt.xlabel('Number of weigths')
    plt.ylabel('Value of the weights')

# %%
values = [10.,20.,30.,40.,50.]
for i in range (len(values)): 
    rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, idx_monitored_neurons_excit, rate_monitor_inhib, spike_monitor_inhib, voltage_monitor_inhib, idx_monitored_neurons_inhib, weight_profile_45 = wm_model.simulate_wm(sim_time=800. * b2.ms, poisson_firing_rate=1.3 * b2.Hz, sigma_weight_profile=values[i], Jpos_excit2excit=2.3)
    plot_tools.plot_network_activity(rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, t_min=0. * b2.ms)

    plt.figure()
    plt.plot(weight_profile_45)
    plt.title('Weight profil for sigma_weight_profile = {}'.format(values[i]))
    plt.xlabel('Number of weigths')
    plt.ylabel('Value of the weights')

# %% [markdown]
# Answer here to the comment questions (max 6 lines overall).
#
# #### [ 5  points]
#
# As we increase the value of Jpos_excit2excit, we observe an increase in weight values as we can observe thanks to the vertcial scale. However, the profile of the curve always stays a more or less narrow gaussian with maximum of 2.25 and miminum 0.8.
# As for the other curves, for Jpos_excit2excit=2.3 we can see a better defined gaussian (less noise) profile centered in 180 where the maximal weigth values reached 2.3 showing that the population activity also increased.
# The variance of the weigths defines the width of the bump. Thus, as we increase the variance, the width of the bump increases and the weight profile become less steep. Futhermore, we also observed that increasing the bump (/Variance) width led to higher population activity. Finally, if the variance is too small the bump does not appear.

# %% [markdown]
# # Exercise 12.2. Network response to a structured input stimulus

# %%
import brian2 as b2
from neurodynex.working_memory_network import wm_model
from neurodynex.tools import plot_tools
import matplotlib.pyplot as plt

print ('Plot with the stimulus stenght equal to 0.06namp :')
rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, idx_monitored_neurons_excit, rate_monitor_inhib, spike_monitor_inhib, voltage_monitor_inhib, idx_monitored_neurons_inhib, w_profile = wm_model.simulate_wm(stimulus_center_deg=120, stimulus_width_deg=30, stimulus_strength=.06 * b2.namp, t_stimulus_start=100 * b2.ms, t_stimulus_duration=200 * b2.ms, sim_time=500. * b2.ms)
fig, ax_raster, ax_rate, ax_voltage = plot_tools.plot_network_activity(rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, t_min=0. * b2.ms)
plt.show()

print('Plot with the stimulus stenght equal to 0.5namp :')
rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, idx_monitored_neurons_excit, rate_monitor_inhib, spike_monitor_inhib, voltage_monitor_inhib, idx_monitored_neurons_inhib, w_profile = wm_model.simulate_wm(stimulus_center_deg=120, stimulus_width_deg=30, stimulus_strength=.5 * b2.namp, t_stimulus_start=100 * b2.ms, t_stimulus_duration=200 * b2.ms, sim_time=500. * b2.ms)
fig, ax_raster, ax_rate, ax_voltage = plot_tools.plot_network_activity(rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, t_min=0. * b2.ms)
plt.show()
# Out:
# Plot with the stimulus stenght equal to 0.06namp :
# Plot with the stimulus stenght equal to 0.5namp :

# %%
print('Plot with the stimulus width equal to 30deg (stimulus_strength=0.1 * b2.namp, stimulus center = 120deg):')
rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, idx_monitored_neurons_excit, rate_monitor_inhib, spike_monitor_inhib, voltage_monitor_inhib, idx_monitored_neurons_inhib, w_profile = wm_model.simulate_wm(stimulus_center_deg=120, stimulus_width_deg=30, stimulus_strength=.5 * b2.namp, t_stimulus_start=100 * b2.ms, t_stimulus_duration=200 * b2.ms, sim_time=500. * b2.ms)
plot_tools.plot_network_activity(rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, t_min=0. * b2.ms)
plt.figure()
plt.plot(weight_profile_45)
plt.title('Weight profil for stimulus width equal to 30deg')
plt.xlabel('Number of weigths')
plt.ylabel('Value of the weights')
plt.show()

print('Plot with the stimulus width equal to 60deg (stimulus_strength=0.1 * b2.namp, stimulus center = 120deg):')
rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, idx_monitored_neurons_excit, rate_monitor_inhib, spike_monitor_inhib, voltage_monitor_inhib, idx_monitored_neurons_inhib, w_profile = wm_model.simulate_wm(stimulus_center_deg=120, stimulus_width_deg=30, stimulus_strength=.5 * b2.namp, t_stimulus_start=100 * b2.ms, t_stimulus_duration=200 * b2.ms, sim_time=500. * b2.ms)
plot_tools.plot_network_activity(rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, t_min=0. * b2.ms)
plt.figure()
plt.plot(weight_profile_45)
plt.title('Weight profil for stimulus width equal to 60deg')
plt.xlabel('Number of weigths')
plt.ylabel('Value of the weights')
plt.show()
# Out:
# Plot with the stimulus width equal to 30deg (stimulus_strength=0.1 * b2.namp, stimulus center = 120deg):
# Plot with the stimulus width equal to 60deg (stimulus_strength=0.1 * b2.namp, stimulus center = 120deg):

# %% [markdown]
# ### Exercise 12.2.1. Question: Integration of input
#
# #### [5  points]

# %% [markdown]
# At which time can you identify a change in the population activity? How does that compare to the time when the stimulus is applied?
# ANSWER: We can identify a change in the population activity around t=200 ms. The stimulus starts at t=100 ms and terminates at t=300 ms. Thus the change in population activity happens 100 ms after the stimulus (t=200ms).
#
# What is the population activity at the end of the simulation?
# ANSWER: The population activity at the end (t=300 ms) of the simulation was around 15Hz.
#
# For the time point t=400ms, sketch the firing rate across the population (neuron index on the x-axis, per-neuron firing rate on the y-axis).
# ANSWER: A gaussian centered around neuron number 300 with a variance of approximatly ±50 would be sketched. We can deduce these numbers thanks to the population activity plot. However, since it is not possible to submit any additional files it is not possible to see the sketch.
#
# Increase the stimulus strength to 0.5namp. What happens when the stimulus stops?
# ANSWER: When the stimulus stops at t=300ms, the population activity drops from 15 Hz to 10 Hz after having increased the stimulus strength to 0.5 nA. However the final activity stays higher than the initial.
#
# Increase the stimulus width to 60deg (stimulus_strength=0.1 * b2.namp, stimulus center = 120deg). How does the bump shape change? ANSWER: An increase in the stimulus width to 60 deg (stimulus_strength=0.1 * b2.namp, stimulus center = 120deg) did not change the bump shape. The only thing that was observed was an increase in the population activity in comparison to the previous experiment.

# %% [markdown]
# ### Exercise 12.2.2. Question: Role of the inhibitory population
#
# #### [2+1+1+2  points]

# %% [markdown]
# Before running the simulation: What do you expect to see? (max 2 lines)
#
# ANSWER: We exepected to see a high population activity. Since there is no inhibition in the model anymore and only the recurrent weigth remain, we expect high synchronous activation with some periods of refractoriness since the neurons cannot always fire.

# %%
print('Plot with none neuron inhibited ')
rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, idx_monitored_neurons_excit, rate_monitor_inhib, spike_monitor_inhib, voltage_monitor_inhib, idx_monitored_neurons_inhib, w_profile = wm_model.simulate_wm(N_inhibitory=1,stimulus_center_deg=120, stimulus_width_deg=60, stimulus_strength=.65 * b2.namp, t_stimulus_start=5 * b2.ms, t_stimulus_duration=25 * b2.ms, sim_time=80. * b2.ms)
fig, ax_raster, ax_rate, ax_voltage = plot_tools.plot_network_activity(rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, t_min=0. * b2.ms)
plt.show()
# Out:
# Plot with none neuron inhibited

# %% [markdown]
# We saw what we expected. From the first plot we see that there is a high population activity (high rate of neuron is firing). From the second plot we observe an oscillation in the activity of the neurons which is the alternance between spiking and refractoriness which is typical of a neuron activity. Futhermore from the second plot we observe that the activity is high around 500 Hz. Finally, it was interesting to see that all the neurons are firing at the same time which confirms all the hypothesis states in the previous question.

# %% [markdown]
# Now run again a “normal” simulation:

# %%
print ('COntrol Simulation with inhibitory population')
rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, idx_monitored_neurons_excit, rate_monitor_inhib, spike_monitor_inhib, voltage_monitor_inhib, idx_monitored_neurons_inhib, w_profile = wm_model.simulate_wm(stimulus_center_deg=120, stimulus_width_deg=30, stimulus_strength=.06 * b2.namp, t_stimulus_start=100 * b2.ms, t_stimulus_duration=200 * b2.ms, sim_time=500. * b2.ms)
fig, ax_raster, ax_rate, ax_voltage = plot_tools.plot_network_activity(rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, t_min=0. * b2.ms)
plt.show()
# Out:
# COntrol Simulation with inhibitory population

# %% [markdown]
# What is the role of the inhibitory population? (max 2 lines)

# %% [markdown]
# The role of the inihibitory is to maintain the activity of the population at a reasonable level/frequency by selectively inhibiting neurons with high activity for the given input stimulus. We see that by restoring the population of inhibitory that the activity is around 15Hz whereas before it was around 500 Hz.

# %% [markdown]
# # Exercise 12.3: Decoding the population activity into a population vector

# %% [markdown]
# ### Exercise 12.3.1. Mapping the neuron index onto its preferred direction
#
# #### [3 points]

# %%
# write your code here
def get_orientation(idx_list, N): 
    new_idx = []
    for i in range (len(idx_list)):
        new_idx.append((idx_list[i]+0.5)*360/N)
    return new_idx

# %%
get_orientation([0, 1, 5, 10], 11)
# Out:
# [16.363636363636363, 49.09090909090909, 180.0, 343.6363636363636]

# %%
get_orientation([0, 1, 499, 500, 999], 1000)
# Out:
# [0.18, 0.54, 179.82, 180.18, 359.82]

# %% [markdown]
# ### Exercise 12.3.2. Extracting spikes from the spike monitor
#
#
# #### [ 4  points]

# %%
import numpy as np
# modify the following code
def get_spike_count(spike_monitor, spike_index_list, t_min, t_max):
    nr_neurons = len(spike_index_list)
    spike_count_list = np.zeros(nr_neurons)
    spike_trains = spike_monitor.spike_trains()
    
    for i, j in enumerate(spike_index_list): 
    #spike_index_list is a 2D vector in i we look at the angle whereas in j we observe 
    #the time at which we saw a spike. Then we compute a boolean which is one if we are in the the time window. 
    # loop over the list of neurons and get the spikes within the time window:
        tmp = (spike_trains[j]>=t_min) & (spike_trains[j]<(t_max))  # try sum(list of booleans)
        spike_count_list[i] = sum(tmp)
    return spike_count_list

# %%
import matplotlib.pyplot as plt

t = 400*b2.ms  # time point of interest
t_window = 10*b2.ms # width of the window over which the average is taken

t_min = t-t_window/2
t_max = t+t_window/2
spike_counts = get_spike_count(spike_monitor_excit, idx_monitored_neurons_excit, t_min, t_max)
spike_rates = spike_counts/(t_max-t_min)/b2.second
plt.plot(spike_rates, ".b")
plt.title("Bump profile in the time interval[{},{}]".format(t_min, t_max))
plt.xlabel("Neuron index")
plt.ylabel("Spike rate [Hz]")
# Out:
# Text(0,0.5,u'Spike rate [Hz]')

# %% [markdown]
# ### Exercise 12.3.3. Computing the population vector
#
# #### [3  points]

# %%
def get_theta_time_series(spike_monitor, idx_monitored_neurons, t_snapshots, t_window_width):
#we tried to find the neurons indices of the neuros that fire the most, 
#we retrive the indices and convert the indices with get orientation
    theta_ts=[]
    for i in range (len(t_snapshots)): 
        t_min = t_snapshots[i]-t_window_width/2
        t_max = t_snapshots[i]+t_window_width/2
        spike_count_list = get_spike_count(spike_monitor, idx_monitored_neurons, t_min, t_max)  
        spike_rates = spike_count_list/(t_max-t_min)/b2.second #convert amount in rates 
        max_rate = max(spike_rates)
        max_idxs = [k for k, j in enumerate(spike_rates) if j == max_rate] #find max rate of firing and link it to favorite angles 
        
        theta_ts.append(np.mean(get_orientation(max_idxs, len(idx_monitored_neurons))))

    return theta_ts

# %%
import math

t_stimulus_start=100 * b2.ms
t_stimulus_duration=200 * b2.ms
t_sim=500. * b2.ms
t_window_width = 10*b2.ms # width of the window over which the average is taken
snapshot_interval = 10*b2.ms

# Example how to create an array of timestamps spaced by snapshot_interval in the interval of interest.
t_snapshots = range(
    int(math.floor((t_stimulus_start+t_stimulus_duration)/b2.ms)),  # lower bound
    int(math.floor((t_sim-t_window_width/2)/b2.ms)),  # Subtract half window. Avoids an out-of-bound error later.
    int(round(snapshot_interval/b2.ms))  # spacing between time stamps
    )*b2.ms

# how your function get_theta_time_series could be called:
theta_ts = get_theta_time_series(spike_monitor_excit, idx_monitored_neurons_excit, t_snapshots, t_window_width)

# plot theta vs time using pyplot
import matplotlib.pyplot as plt
plt.plot(t_snapshots/b2.ms, theta_ts)
plt.title('Evolution of the thetha in function of time')
plt.xlabel('time (in ms)')
plt.ylabel('Thetha(t)')
# Out:
# Text(0,0.5,u'Thetha(t)')

# %% [markdown]
# ### Exercise 12.3.4. Exercise: Visualize the diffusion of the population vector
#
# #### [3 (coding) + 2 (discussion) points]

# %%
import matplotlib.pyplot as plt

#N=2048
t_stimulus_start=100 * b2.ms
t_stimulus_duration=300 * b2.ms
t_sim=2000. * b2.ms
t_window_width = 100*b2.ms # width of the window over which the average is taken
snapshot_interval = 20*b2.ms
theta_ts=[]

for i in range(3):
    rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, idx_monitored_neurons_excit, rate_monitor_inhib, spike_monitor_inhib, voltage_monitor_inhib, idx_monitored_neurons_inhib, w_profile = wm_model.simulate_wm(N_excitatory=2048, stimulus_center_deg=120, stimulus_width_deg=30, stimulus_strength=.65 * b2.namp, t_stimulus_start=t_stimulus_start, t_stimulus_duration=t_stimulus_duration, sim_time=t_sim)
    # Example how to create an array of timestamps spaced by snapshot_interval in the interval of interest.
    t_snapshots = range(
        int(math.floor((t_stimulus_start+t_stimulus_duration)/b2.ms)),  # lower bound
        int(math.floor((t_sim-t_window_width/2)/b2.ms)),  # Subtract half window. Avoids an out-of-bound error later.
        int(round(snapshot_interval/b2.ms))  # spacing between time stamps
        )*b2.ms

    # how your function get_theta_time_series could be called:
    theta_ts.append(get_theta_time_series(spike_monitor_excit, idx_monitored_neurons_excit, t_snapshots, t_window_width))

    # plot theta vs time using pyplot
    plt.plot(t_snapshots/b2.ms, theta_ts[i])
    plt.title('Population vector. N-excitatory= 2048 Neurons, Stimulus center= 120 deg')
    plt.xlabel('Time (in ms)')
    plt.ylabel('Population vector (in degrees)')
    
plt.show()

# %%
#N=512
t_stimulus_start=100*b2.ms
t_stimulus_duration=300*b2.ms
t_sim=2000.*b2.ms
t_window_width = 100*b2.ms # width of the window over which the average is taken
snapshot_interval = 20*b2.ms
theta_ts=[]

for i in range(3):
    rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, idx_monitored_neurons_excit, rate_monitor_inhib, spike_monitor_inhib, voltage_monitor_inhib, idx_monitored_neurons_inhib, w_profile = wm_model.simulate_wm(N_excitatory=512, stimulus_center_deg=120, stimulus_width_deg=30, stimulus_strength=.1 * b2.namp, t_stimulus_start=t_stimulus_start, t_stimulus_duration=t_stimulus_duration, sim_time=t_sim)

    # Example how to create an array of timestamps spaced by snapshot_interval in the interval of interest.
    t_snapshots = range(
        int(math.floor((t_stimulus_start+t_stimulus_duration)/b2.ms)),  # lower bound
        int(math.floor((t_sim-t_window_width/2)/b2.ms)),  # Subtract half window. Avoids an out-of-bound error later.
        int(round(snapshot_interval/b2.ms))  # spacing between time stamps
        )*b2.ms

    # how your function get_theta_time_series could be called:
    theta_ts.append(get_theta_time_series(spike_monitor_excit, idx_monitored_neurons_excit, t_snapshots, t_window_width))

    # plot theta vs time using pyplot
    plt.plot(t_snapshots/b2.ms, theta_ts[i])
    plt.title('Population vector: N-excitatory=512 Neurons, Stimulus center = 120 degrees')
    plt.xlabel('Time (in ms)')
    plt.ylabel('Population vector (in degrees)')
    
plt.show()

# %% [markdown]
# *Write your obeservation here (max 4 lines)*

# %% [markdown]
# For the N_excitatory=2048 neurons we saw that there were some variations between the three different models that we generated. These variations tend to be smaller while reducing the number of excitatory neurons to 512 neurons. However, we saw that changing the number excitatory neurons did have an influence on the magnitude of the oscillations: The smaller population was, the greater the fluctuations were ($\pm5$ for N=2048 to $\pm25$ for N=512). Nevertheless, one could see that all the curves were oscillating around the same mean value which means that the basic information between the models is shared.

# %% [markdown]
# # Exercise 12.4. Reading exercise: slow and fast channels

# %% [markdown]
# ### Exercise 12.4.1.
#
# #### [2 points]
# Write your answer here (max 2 lines).
#
# By looking at the documentation and the code we observed the tau values of the two NMDA receptors. The NMDAs' tau was 65 ms whereas the NMDAx' tau was 1.88 ms. Thus, the NMDAx receptors represent the fast rise whereas NMDAs showed the slow decay.

# %% [markdown]
# # Exercise 12.5: Effect of disinhibition on the bump shape
# ### *** Note:*** this exercise is not available online, all necessary information is given here.
#
# In this exercise we will try to reproduce the results of the paper "*Linking Microcircuit Dysfunction to Cognitive Impairment: Effects of Disinhibition Associated with Schizophrenia in a Cortical Working Memory Model*" (https://academic.oup.com/cercor/article/24/4/859/321897).
# As you can read in the abstract, "Excitation–Inhibition balance (E/I balance) is a fundamental property of cortical microcircuitry. Disruption of E/I balance in prefrontal cortex is hypothesized to underlie cognitive deficits observed in neuropsychiatric illnesses such as schizophrenia".
# In order to understand this exerise, you do not need to read the full paper, but you will need to get a general understanding of the research topic (we recommend to read the abstract) and a detailed understanding of figures  1, 2 and 5 (make sure you understand the meaning of the quantities involved in those plots).
#
# In this paper, the authors pharmacologically alter the E/I balance in the prefrontal cortex through the use of a drug which reduces the conductance of the excitatory-to-inhibitory  synapses, $G_{EI}$.
# In this way, the inhibitory neurons are less activated and therefore the excitatory neurons are disinhibited.
# In other words, they pharmacologically induce the specific symptoms they what to understand.
#
# More interestingly, from our perspective, they use an analogous model that you have been using so far in order to understand **why** disinhibition is associated with some of the symptons of schizophrenia, such as a reduced ability of keeping the focus on a fixation point.
#
# **Note:**  In what follows we will reproduce qualitatively some of the results shown in the paper's figures. However a perfect match between numerical values cannot be achieved as our neural network slightly differs from that of the paper.
#
# ### Exercise 12.5.1
# #### [4 points]
# As a starting point, we can see qualitatively the effect of disinhibition on the bump width by running the simulation with two different values of $G_{EI}$ (in the code, $G_{EI}$ is "G_excit2inhib"). The plot should be qualitatively similar to Fig. 2.A of the paper.

# %%
# %matplotlib inline
import brian2 as b2
from neurodynex.working_memory_network import wm_model
from neurodynex.tools import plot_tools
import numpy as np
import matplotlib.pyplot as plt
from math import ceil, floor

print('TEST')
# repeat the following passeages for the desired values of G_EI
rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, idx_monitored_neurons_excit, rate_monitor_inhib, spike_monitor_inhib, voltage_monitor_inhib, idx_monitored_neurons_inhib, w_profile = wm_model.simulate_wm(G_excit2inhib=122.64*(1-0.0925)*b2.psiemens, stimulus_center_deg=90, stimulus_width_deg=30, stimulus_strength=.3*b2.namp, t_stimulus_start=100*b2.ms, t_stimulus_duration=250*b2.ms, sim_time=500.*b2.ms)
fig, ax_raster, ax_rate, ax_voltage = plot_tools.plot_network_activity(rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, t_min=0. * b2.ms)
plt.suptitle("9.25 % of disinhibition reduced")
plt.show()
# Out:
# TEST

# %%
print('CONTROL')
rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, idx_monitored_neurons_excit, rate_monitor_inhib, spike_monitor_inhib, voltage_monitor_inhib, idx_monitored_neurons_inhib, w_profile = wm_model.simulate_wm(stimulus_center_deg=90, stimulus_width_deg=30, stimulus_strength=.3*b2.namp, t_stimulus_start=100*b2.ms, t_stimulus_duration=250*b2.ms, sim_time=500.*b2.ms)
fig, ax_raster, ax_rate, ax_voltage = plot_tools.plot_network_activity(rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, t_min=0. * b2.ms)
plt.show()
# Out:
# CONTROL

# %% [markdown]
# ### Exercise 12.5.2
# #### [5 points]
#
# In exercise 12.3.2 you plotted the profile of the bump. Starting from the the bump profile, write the function bump_width() that measures the bump's width. In order to measure the width of the bump, we take the full width at half maximum.

# %%
# this function is useful to compute the bump width
def find_nearest_argmin(array,value):
    idx = (np.abs(array-value)).argmin()
    return idx 

def bump_width(spike_counts, t_min, t_max):  
    if len(spike_counts)==0:
        return [0]
    else:
        spike_rates = spike_counts/(t_max-t_min)/b2.second   # use the function get_spike_count
        half_max_rate = np.max(spike_rates)/2 
        peak_position = np.argmax(spike_rates)
        left_bump_boundary = find_nearest_argmin(spike_rates[0:int(peak_position)], half_max_rate)# use the find_nearest_argmin to determine the left bump boundary
        right_bump_boundary = find_nearest_argmin(spike_rates[int(peak_position):-1], half_max_rate)# use the find_nearest_argmin to determine the right bump boundary
        bump_size = right_bump_boundary - left_bump_boundary
        return bump_size

# %% [markdown]
# ### Exercise 12.5.3
# #### [ 6 (for the simulation) + 6 (for the plots) points]
# In this exercise we reproduce figures 2.C and 2.D of the paper.
#
# You will need to use the fucntion bump_width() to plot the bump's width vs the decrease of $G_{EI}$ in percentage, in order to reproduce Fig. 2.B of the paper.
#
# On the other hand you will need to use the function get_theta_time_series, in order to extract the poplation vector (which in the paper is called $\theta_{report}$ or just "report").
# It is important to chose a proper time bin (such that you filter out the oscillations, but you can still capture the drift of the population vector).
#
# **Parameters for the stimulus:** N_excitatory=1024, N_inhibitory=256, stimulus_center_deg=180, stimulus_width_deg=40, stimulus_strength=0.3 namp, t_stimulus_start=10 ms, t_stimulus_duration=100 ms, distractor_center_deg=120, distractor_width_deg=0, distractor_strength=0. namp, t_distractor_start=0 ms, t_distractor_duration=0 ms, G_excit2inhib = (1. - ?) .35 x 1.2 x 0.292  nS, sim_time=500. ms
#
# **Making the plots**
#
# In the same for-loop (on differnt values of $G_{EI}$) you can store the bump's width, population vector for the excitatory group and that of the inhibitory group. This will allow  you to save computational time!
# Then make two plots corresponding to Fig. 2.C and 2.D.

# %%
resolution=10   # how many data points we want in the graph
n_trials=5 # number of trial on which we average every point in the graph
disinhibition_level=np.linspace(0.,0.14, resolution)   # define the range of values of the disinhibition
t_min=10*b2.ms
t_max=500.*b2.ms
N_excitatory=1024
N_inhibitory=256

# here we initialize the arrays in which we are goint to store the quantity we need to plot
bump_w=np.array([0.]*resolution)
bump_std=np.array([0.]*resolution)

firing_rate_E=np.array([0.]*resolution)
firing_rate_E_std=np.array([0.]*resolution)

firing_rate_I=np.array([0.]*resolution)
firing_rate_I_std=np.array([0.]*resolution)

for i in range(resolution):
    
    bump_local=[0]*n_trials
    for j in range(n_trials):
        rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, idx_monitored_neurons_excit, rate_monitor_inhib, spike_monitor_inhib, voltage_monitor_inhib, idx_monitored_neurons_inhib, w_profile = wm_model.simulate_wm(N_excitatory=1024, N_inhibitory=256, stimulus_center_deg=180, stimulus_width_deg=40, stimulus_strength=0.3*b2.namp, t_stimulus_start=10*b2.ms, t_stimulus_duration=100*b2.ms, distractor_center_deg=120, distractor_width_deg=0, distractor_strength=0. *b2.namp, t_distractor_start=0*b2.ms, t_distractor_duration=0*b2.ms, G_excit2inhib = (1.0-disinhibition_level[i])*0.35*1.2*0.292*b2.nS, sim_time=500.*b2.ms)      
        angle_degree = 1024/360.  # neural index to angle scaling factor 
        spike_counts = get_spike_count(spike_monitor_excit, idx_monitored_neurons_excit, t_min, t_max)
        bump_local[j]= bump_width(spike_counts, t_min, t_max)/angle_degree
        
    bump_w[i]= np.mean(bump_local) # compute the mean of the bump_width_local
    bump_std[i]= np.std(bump_local) # compute the std of the bump_width_local
    
    # here we extract the rates from the monitors
    rate_excit = rate_monitor_excit.smooth_rate(window="flat", width=0.5*b2.ms)/b2.Hz
    rate_inhib = rate_monitor_inhib.smooth_rate(window="flat", width=0.5*b2.ms)/b2.Hz
    
    last20_excit = int(len(rate_excit)*0.8)
    firing_rate_E[i] = np.mean(rate_excit[last20_excit:-1])# compute the mean of rate_excit over the last 20% of entries 
    firing_rate_E_std[i] = np.std(rate_excit[last20_excit:-1])# compute the std of rate_excit over the last 20% of entries 
    
    last20_inhib  = int(len(rate_inhib)*0.8)
    firing_rate_I[i] = np.mean(rate_inhib[last20_inhib:-1]) # compute the mean of rate_inhib over the last 20% of entries
    firing_rate_I_std[i] = np.std(rate_inhib[last20_inhib:-1]) # compute the std of rate_inhib over the last 20% of entries  
    print('step {} finished'.format(i+1))
# Out:
# INFO       width adjusted from 0.5 ms to 0.55 ms [brian2.monitors.ratemonitor.adjusted_width]
# step 1 finished
# step 2 finished
# step 3 finished
# step 4 finished
# step 5 finished
# step 6 finished
# step 7 finished
# step 8 finished
# step 9 finished
# step 10 finished

# %%
# reproducing Fig 2.C of the paper: 
# plot the bump_width vs disinhibition_level +- its std
 
plt.errorbar(disinhibition_level,bump_w+180,bump_std)   
plt.xlabel('reduction of $G_{EI}$')
plt.ylabel('Bump width [degrees]')
plt.title('Bump width as a function of the degree of disinhibition')
plt.show()

# reproducing Fig 2.D of the paper
# plot the change in firing rates vs disinhibition_level +- its std. 
#Let's start with the excitatory population.

# first you need to express the firing rates changes in percentage
#firing_rate_E_perc = firing_rate_E/max(firing_rate_E)*100
# and the std firing_rate_E_std_perc = firing_rate_E_std/max(firing_rate_E_std)*100
firing_rate_E_perc = (firing_rate_E-firing_rate_E[0])/firing_rate_E[0]
firing_rate_E_std_perc = (firing_rate_E_std-firing_rate_E_std[0])/firing_rate_E_std[0]
# plot the firing rate change of the exc pop +- its std dev
plt.errorbar(disinhibition_level, firing_rate_E_perc*100, firing_rate_E_std_perc*100, label='Excitatory population')

# repeat the same passages for the inhibitory population
#firing_rate_I_perc = firing_rate_I/max(firing_rate_I)*100
#firing_rate_I_std_perc =  firing_rate_I_std/max(firing_rate_I_std)*100
firing_rate_I_perc = (firing_rate_I-firing_rate_I[0])/firing_rate_I[0]
firing_rate_I_std_perc = (firing_rate_I_std-firing_rate_I_std[0])/firing_rate_I_std[0]
plt.errorbar(disinhibition_level, firing_rate_I_perc*100, firing_rate_I_std_perc*100, label='Inhibitory population')

plt.xlabel('reduction of $G_{EI}$')
plt.ylabel('firing rate [change in %]')
plt.title('Firing rates as a function of the degree of disinhibition')
plt.legend()
plt.show()

# %% [markdown]
# # Exercise 12.6
# In this exercise we study the combined effect of a distractor and disinhibition. Therefore we will focus on Fig. 5 of the paper.

# %% [markdown]
# ### Exercise 12.6.1
# #### [4 points]
# Reproduce Fig. 5.A: use the proper keywords in the function simulate_wm in order to introduce a distractor in the system. Choose a value of the keyword "distractor_center_deg" and two values of $G_{EI}$ such that you qualitatively reproduce Fig. 5.A.
#
# **Hint:** For the control case we use the default value of $G_{EI}$ and in the disinhibition case we lower that value by 10%. Simulate for 500ms (keyword sim_time).
#
# **Stimulus parameters:** N_excitatory=1024, N_inhibitory=256, stimulus_center_deg=90, stimulus_width_deg=40, stimulus_strength=0.3 namp, t_stimulus_start=10 ms, t_stimulus_duration=100 ms
#
# **Distractor parameters:** The distractor should have the same strenght, width and duration as the stimulus and should kick in 200ms after the stimulus starts. The position of the distract should be 90˚ higher than the stimulus, just as in the paper figure.

# %%
# Reproduction of plot 5A in paper
# raster plot bump with distractor for control case
#rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, idx_monitored_neurons_excit, rate_monitor_inhib, spike_monitor_inhib, voltage_monitor_inhib, idx_monitored_neurons_inhib, w_profile = wm_model.simulate_wm( N_excitatory=1024, N_inhibitory=256, stimulus_center_deg=90, stimulus_width_deg=40, stimulus_strength=0.3 *b2.namp, t_stimulus_start=10 *b2.ms, t_stimulus_duration=100*b2.ms, sim_time=500*b2.ms )
rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, idx_monitored_neurons_excit, rate_monitor_inhib, spike_monitor_inhib, voltage_monitor_inhib, idx_monitored_neurons_inhib, w_profile = wm_model.simulate_wm(N_excitatory=1024, N_inhibitory=256, stimulus_center_deg=90, stimulus_width_deg=40, stimulus_strength=0.3*b2.namp, t_stimulus_start=10*b2.ms, t_stimulus_duration=100*b2.ms, distractor_center_deg=90+90, distractor_width_deg=40, distractor_strength=0.3*b2.namp, t_distractor_start=(10+200)*b2.ms, t_distractor_duration=100*b2.ms, sim_time=500.*b2.ms)
fig, ax_raster, ax_rate, ax_voltage = plot_tools.plot_network_activity( rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, t_min=0.*b2.ms )
plt.suptitle("Control")
plt.show()


# raster plot bump with distractor with disinhibition
# rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, idx_monitored_neurons_excit, rate_monitor_inhib, spike_monitor_inhib, voltage_monitor_inhib, idx_monitored_neurons_inhib, w_profile  = wm_model.simulate_wm( N_excitatory=1024, N_inhibitory=256, stimulus_center_deg=90, stimulus_width_deg=40, stimulus_strength=0.3 *b2.namp, t_stimulus_start=10 *b2.ms, t_stimulus_duration=100*b2.ms, sim_time=500*b2.ms, G_excit2inhib=122.64*0.9*b2.psiemens)
rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, idx_monitored_neurons_excit, rate_monitor_inhib, spike_monitor_inhib, voltage_monitor_inhib, idx_monitored_neurons_inhib, w_profile = wm_model.simulate_wm(N_excitatory=1024, N_inhibitory=256, stimulus_center_deg=90, stimulus_width_deg=40, stimulus_strength=0.3*b2.namp, t_stimulus_start=10 *b2.ms, t_stimulus_duration=100 *b2.ms, distractor_center_deg=90+90, distractor_width_deg=40, distractor_strength=0.3*b2.namp, t_distractor_start=(10+200)*b2.ms, t_distractor_duration=100*b2.ms, sim_time=500.*b2.ms,G_excit2inhib=122.64*0.9*b2.psiemens)

fig, ax_raster, ax_rate, ax_voltage = plot_tools.plot_network_activity( rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, t_min=0.*b2.ms  )
plt.suptitle("10 % disinhibition")
plt.show()

# %% [markdown]
# ### Exercise 12.6.2
# #### [8 (for the coding) + 6 (for plots) + 3 (for the discussion) points]
# 1) Use the function "get_theta_time_series" as you did in exercise 5.3 in order to compute $\theta_{report}$ for different positions of the distractor and for 3 values of $G_{EI}$ such that $G_{EI}$ is reduced by 0,7 and 14 % respectively.
#
# 2) Reproduce Fig. 5.B: Plot $\theta_{report}$ as a function of the distractor position for a variation of $G_{EI}$ of 0, 7 and 14% (3 curves).
#
# 3) Comment the graph you made in point 2: how can we interpret the curves? How can we explain their shapes? Why is the maximum of each curve shifted to the right in the case of disinhibition? (Max 10 lines)

# %%
from math import floor, ceil
import math

b2.defaultclock.dt = 0.05*b2.ms
t_sim= 500*b2.ms

t_stimulus_start = 10*b2.ms
t_stimulus_duration = 100*b2.ms
stimulus_center_deg = 90
stimulus_width_deg = 40
stimulus_strength = 0.3*b2.namp

t_distractor_start = 210*b2.ms
t_distractor_duration = 100*b2.ms
distractor_width_deg = 40
distractor_strength = 0.3*b2.namp

# distractor angles
rel_distr_angles = np.array([0, 25, 50, 75, 100, 125, 150, 175])
distr_angles = rel_distr_angles + stimulus_center_deg

# synaplse relevant for disinhibtion,  this will also be looped over in the following
disinhib_percentages = np.array([0, 0.07, 0.14 ])
G_excit2inhib_control =  .35 * 1.2 * 0.292 * b2.nS

N_excit = 512
N_inhib = 128
weight_scaling = 4

t_window_length = 100*b2.ms
snapshot_interval = 20*b2.ms
n_trials = 4 # increase or decrease the number of trials on the base of the tradeoff between the simulation time and the quality of the outcome

t_snapshots = range(int(floor((t_stimulus_start+t_stimulus_duration-t_window_length)/b2.ms)), int(ceil((t_sim-t_window_length)/b2.ms)), int(round(snapshot_interval/b2.ms)))*b2.ms
report = [[[[] for i in range(n_trials)] for j in range(len(distr_angles))] for k in range(len(disinhib_percentages))]
distractibility_windows = [[] for i in range(len(disinhib_percentages))]

t_min=t_snapshots-t_window_length/2
t_max=t_snapshots+t_window_length/2

for k in range(len(disinhib_percentages)):
    G_excit2inhib = (1-disinhib_percentages[k])*G_excit2inhib_control
    for i in range(len(distr_angles)):
        distractor_center_deg = distr_angles[i] # set the correct value of the distractor angular position
        
        for j in range(n_trials):
            rate_monitor_excit, spike_monitor_excit, voltage_monitor_excit, idx_monitored_neurons_excit, rate_monitor_inhib, spike_monitor_inhib, voltage_monitor_inhib, idx_monitored_neurons_inhib, w_profile = wm_model.simulate_wm(N_excitatory = N_excit, N_inhibitory = N_inhib, weight_scaling_factor = weight_scaling,
                    stimulus_center_deg=stimulus_center_deg, stimulus_width_deg=stimulus_width_deg, stimulus_strength=stimulus_strength,
                    t_stimulus_start=t_stimulus_start, t_stimulus_duration=t_stimulus_duration,
                    distractor_center_deg=distractor_center_deg, distractor_width_deg=distractor_width_deg, distractor_strength=distractor_strength,
                    t_distractor_start=t_distractor_start, t_distractor_duration=t_distractor_duration,
                    G_excit2inhib = G_excit2inhib,
                    sim_time=t_sim)
            
            theta_list = get_theta_time_series( spike_monitor_excit, idx_monitored_neurons_excit,  t_snapshots, snapshot_interval  ) # extract the population vector as before
            last_90 = int(len(theta_list)*0.90)
            report[k][i][j] = np.mean(theta_list[last_90:-1]) # compute the mean of theta_list over the last 10% of entries 

# average over repetitions/initializations
report_averaged = np.mean(report, axis=2) # compute the mean of the report. Hint: use the keyword axis = 2
report_std = np.std(report, axis=2) # compute the std of the report. Hint: use the keyword axis = 2

# %%
# reproduction of plot 5B in paper
plt.figure()
plt.xlabel(r"Distraction position [$\circ$]")
plt.ylabel(r"Report [$\circ$]")

# in the same graph, plot the report vs. distractor angle curves for the control case and the two disinhibition cases.
# Use the keyword label = ... for the legend

# control curves
# plot the averaged report value vs. the relative distractor angles
# add +- its std. (e.g. as thin, semi-transparent lines above and below)
plt.errorbar(distr_angles-90,report_averaged[0]-90, report_std[0], label='Dishinibition of 0%') # report_averaged[0, :], report_std[0, :])

# ... same for disinhibition 1
plt.errorbar(distr_angles-90,report_averaged[1]-90, report_std[1], label='Dishinibition of 7%')

# ... same for disinhibition 2
plt.errorbar(distr_angles-90,report_averaged[2]-90, report_std[2], label='Dishinibition of 14%')

plt.legend()
plt.title( 'Deviation of report, read out after a 3-s delay, as a function of the angular distance between the distractor and the target' )
plt.show()

# %% [markdown]
# 4) Reproduce Fig. 5.C: extract the argmax of each of the $\theta_{report}$ curves that you computed in point 1 and plot these 4 values as a function of the corresponding variation of $G_{EI}$.

# %%
# plot Fig. 5.C
# extract distractibility window (argmax of report curve, see fig. 5 in the paper)
for i in range(len(disinhib_percentages)):
    distractibility_windows[i] = rel_distr_angles[np.argmax(report_averaged[i][:])]
        
# make the corresponding plot: distract. window against disinhibition percentage
plt.figure()
plt.plot(disinhib_percentages*100, distractibility_windows ,"o-")
plt.xlabel("Percentage of disinhibition")
plt.ylabel(r"Distractibility window [$\circ$]")
plt.title('Increase of the distractibility window as a function of the degree of disinhibition.')
plt.show()

# %% [markdown]
# 5) Compare the plot you made in point 4 with the first one of exercise 12.5.3 (the graph correspondind to Fig. 2.B in the paper) and explain the similarity. (Max 5 lines)

# %% [markdown]
# Both plot look approximately the same. The X-axis is shared whereas on the Y-Axis we are looking at the distractibility window in point 4/ and on the bump width in 12.5.3. This is not surprising since, and as stated in the paper, the distractibility window increases under disinhibition (Fig. 5 B,C), and disinhibition therefore widens the range of distractors that can disrupt WM. This is precisely that is observed in the plots since disinhibition substantially broadens the firing-rate profile of the bump (Fig. 2B,C).

# %%
distractibility_windows
# Out:
# [2, 3, 4]
